# %% [markdown]
# # Loops 1 - While and For

# %% [markdown]
# ---

# %% [markdown]
# ## **Content**

# %% [markdown]
# 1. Need for loops
# 2. `While` loop
# 3. Questions on While loops
# 4. `end` & `sep` in Print
# 5. `For` loop
#     1. List
#     1. `range()`
#     1. Jumps in range()
# 8. Questions on For loops

# %% [markdown]
# ---

# %% [markdown]
# ## **While loop**

# %% [markdown]
# ## **Motivation behind while loops**

# %% [markdown]
# ###**Number Lock**

# %% [markdown]
# - In a number lock with 3 digit key, one would have to iterate digit by digit repetitively until the lock opens, loops can be used here with appropriate condition.

# %% [markdown]
# ![download_1.png](data:image/png;base64,...)

# %% [markdown]
# - On using only conditional statements we would have to check 1000 conditions(from 000 -999)
#
# -
# ```
# While lock is not open:
#     keep trying
# ```
# - Start with 000, if it doesnt work, increase by 1, try again, until lock opens.

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# ##**Code**

# %% [markdown]
# ###**Initialization**
# - where the loop has to start from.
# - if we know the password is >500 we wuld start trying from 501.
#
# ```python
# combnation=0
# ```

# %% [markdown]
# ###**Condition**
# - check the condition where the loop has to stop
#
# ```python
# while(lock still closed): #combination!= actual password
#   try this combination
#
# ```

# %% [markdown]
# ###**Updation**
# update the iterator variable.
# ```python
#   combination+=1
# ```

# %% [markdown]
# ##**Use while loop to print numbers from 1 to 5**

# %% [markdown]
# ```python
# #print(counter)
# #counter+=1
#
# #print(counter)
# #counter+=1
#
# #print(counter)
# #counter+=1
# .
# .
# .
# #n times
# ```

# %%
num=1
while(num<=5):
  print(num)
  num+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## **Coding Exercises**

# %% [markdown]
# ###**Question**: Take an input from user and print all the alternate numbers from 1 till input

# %%
number = int(input("Please input a number - "))
i = 1
while i <= number:
    print(i)
    i += 2
# Out:
# Please input a number - 10
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# **Question**: Take an input from the user for start and end values and print every third number

# %%
start = int(input())
end = int(input())
while start <= end:
    print(start)
    start += 3
# Out:
# 10
# 20
# 10
# 13
# 16
# 19

# %% [markdown]
# ###**Question**: Take an input from the user for start and end values. Print all even numbers between them.

# %% [markdown]
# - Start at the number and print if the number is divisible by 2, increment number by 1

# %%
start = int(input())
end = int(input())
loop_count = 0
while start <= end:
    loop_count += 1
    if start % 2 == 0:
        print(start)
    start += 1
print("Loop was run", loop_count,"times!")
# Out:
# 10
# 20
# 10
# 12
# 14
# 16
# 18
# 20
# Loop was run 11 times!

# %% [markdown]
# - If number is even, start from number, if odd, start from number+1, print number, increment by 2

# %%
start = int(input())
end = int(input())
if start % 2 == 0:
    i = start
else:
    i = start +1
loop_count = 0
while i <= end:
    loop_count += 1
    print(i)
    i += 2
print("Loop was run", loop_count,"times!")
# Out:
# 10
# 20
# 10
# 12
# 14
# 16
# 18
# 20
# Loop was run 6 times!

# %% [markdown]
# - Second answer is more optimized, since the loop runs less number of times.

# %% [markdown]
# ###**Question**: You are a bowler and you have to bowl 1 over. (6 balls) "Bowling ball number - ball_number

# %%
ball_number = 1
while ball_number <= 6:
    print("Bowling ball number -", ball_number)
    ball_number += 1
# Out:
# Bowling ball number - 1
# Bowling ball number - 2
# Bowling ball number - 3
# Bowling ball number - 4
# Bowling ball number - 5
# Bowling ball number - 6

# %% [markdown]
# ###**Question**: Print all numbers from 1 to N (input from user) in a single line.

# %% [markdown]
# - Use **`end =" "`** to print space seperated values on a single line.

# %%
number = int(input())
i = 1
while i <= number:
    print(i, end=" ")
    i += 1
# Out:
# 7
# 1 2 3 4 5 6 7

# %% [markdown]
# ## `end` in print

# %% [markdown]
# - `end` parameter can take values such as " ", "\t", "\n" etc.
#   - " " this means we append a whitespace at the end of our print statement.
#   - "\t" this means we append a tab at the end of our print statement.
#   - "\n" this means we append a newline at the end of our print statement.

# %%
print("random", end="ANYTHING_AT_ALL")
print("print", end="ANYTHING_AT_ALL")
print("statements!",end="ANYTHING_AT_ALL")
# Out:
# randomANYTHING_AT_ALLprintANYTHING_AT_ALLstatements!ANYTHING_AT_ALL

# %% [markdown]
# ##`sep` in print
# - Seperator works like end but for values in the same print statement.

# %%
print("these", "are", "multiple", "strings", 45, 67.8, sep="!WHATEVER!")
# Out:
# these!WHATEVER!are!WHATEVER!multiple!WHATEVER!strings!WHATEVER!45!WHATEVER!67.8

# %% [markdown]
# ##**Question**:
# 1. Take number of test_cases (count) from a user. (Count of numbers)
# 2. Take int(count) inputs from the user
# 3. Print multiplication table for all these inputs!

# %% [markdown]
# ```python
# # 3
#
# # 4
# # multiplication table of 4
# # 5
# # multiplication table of 5
# # 6
# # multiplication table of 6
# ```

# %%
test_cases = int(input())
t = 1
while t <= test_cases:
    number = int(input("Please enter the number -"))
    i = 1
    print("Printing multiplication table of -", number)
    while i <= 10:
        print(number*i, end=" ")
        i += 1
    print("\n")
    t += 1
# Out:
# 2
# Please enter the number -12
# Printing multiplication table of - 12
# 12 24 36 48 60 72 84 96 108 120
#
# Please enter the number -4
# Printing multiplication table of - 4
# 4 8 12 16 20 24 28 32 36 40

# %% [markdown]
# ---

# %% [markdown]
# ###**Quiz-1**

# %% [markdown]
# What will be the output of the following code?
# ```
# x = 1
# while x <= 100:
#     if x % 3 == 0 and x % 5 == 0:
#         print("FizzBuzz")
#     elif x % 3 == 0:
#         print("Fizz")
#     elif x % 5 == 0:
#         print("Buzz")
#     else:
#         print(x)
#     x += 1
# ```
# a) FizzBuzz
#
# b) Fizz
#
# c) Buzz
#
# d) A combination of Fizz, Buzz, and/or integers
#
# **Answer**: d) a combination of Fizz, Buzz, and/or integers

# %% [markdown]
# ---

# %% [markdown]
# # **For Loop**

# %% [markdown]
# ## **Need for `for` loops**

# %% [markdown]
# - While loop will run infinitely when we do not give an exit condition

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# - Instead of a condition, we need a loop that runs for a range

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# - While loop ends when condition becomes false, a for loop ends when the range is exhausted.

# %%
a = input()
while a:
    if len(a) == 6:
        a = ""
    print("END!")

# %% [markdown]
# ### List

# %% [markdown]
# - Multiple values stored in the same variable, in other words, a collection of variables.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### `range()`

# %% [markdown]
# - The square brackets `[]` are inclusive. It means both starting number and ending number are included in the range

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# - The parenthesis `()` are exclusive. It means both starting number and ending number are excluded from the range

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# - The function `range()` has mixed range, it includes the start value, but excludes the end value.

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# - Goes from start to end-1 , [start, end)
# - If start is not given, 0 is start
# - To see all the numbers in the range, use list
# - Length of range is end-start
# - Range does not work with float numbers.

# %%
range(5) # 0 to 4
# Out:
# range(0, 5)

# %%
print(list(range(5)))
# Out:
# [0, 1, 2, 3, 4]

# %%
print(list(range(2,10)))
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9]

# %%
print(list(range(8,8)))
# Out:
# []

# %%
print(list(range(7,8)))
# Out:
# [7]

# %% [markdown]
# - Works with negative ranges

# %%
print(list(range(-1,3)))
# Out:
# [-1, 0, 1, 2]

# %%
print(list(range(-9, -1)))
# Out:
# [-9, -8, -7, -6, -5, -4, -3, -2]

# %% [markdown]
# - By default increment is 1, therefore

# %%
print(list(range(-1,-9)))
# Out:
# []

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Jumps or difference in ranges**

# %% [markdown]
# - range(start,end,jump)

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %%
print(list(range(2,10,2)))
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %%
print(list(range(1,30,3)))
# Out:
# [1, 4, 7, 10, 13, 16, 19, 22, 25, 28]

# %% [markdown]
# - Using for loop in reverse by jumping with negative value

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %%
print(list(range(-1,-9,-1)))
# Out:
# [-1, -2, -3, -4, -5, -6, -7, -8]

# %%
print(list(range(8,8,-1)))
# Out:
# []

# %%
print(list(range(2,5,10)))
# Out:
# [2]

# %%
print(list(range(5,-10,-2)))
# Out:
# [5, 3, 1, -1, -3, -5, -7, -9]

# %% [markdown]
# ---

# %% [markdown]
# ## **Quiz-2**

# %% [markdown]
# What will be the output of `print(list(range(8, 8)))`?
#
# A. `[7]`
#
# B. `[7, 8]`
#
# C. `[]`

# %% [markdown]
# **Ans:** 'C'

# %%
print(list(range(8, 8)))
# Out:
# []

# %% [markdown]
# ---

# %% [markdown]
# ## **Quiz-3**

# %% [markdown]
# How many numbers are included in the below range?
# ```python
# range(1, 11, 2)
# ```
# A. 4
#
# B. 5
#
# C. 6
#
# D. 7

# %% [markdown]
# **Ans:** 'B'

# %% [markdown]
# ---

# %% [markdown]
# ## **Quiz-4**

# %% [markdown]
# How many numbers are included in the below range?
#
# ```python
# range(11)
# ```
#
#   A. 11
#
#   B. 10
#
#   C. 12
#
# **Ans:** 'A'

# %% [markdown]
# ---

# %% [markdown]
# ##**Question**: Calculate sum of all numbers from 1 to N using a for loop.

# %%
number = int(input("Please enter number - "))
final_sum = 0
for value in range(1, number + 1):
    final_sum += value
print(final_sum)

# %% [markdown]
# ##**Question**: Print all numbers from an input N to 1 where N > 1.

# %%
number = int(input("Enter the number - "))
for i in range(number, 0, -1):
    print(i)

# %% [markdown]
# ## **Question**: Print all numbers from an input N to 1 where N > 1 using for loop.SOLVE THIS WITHOUT USING A NEGATIVE JUMP!

# %%
n = int(input("Enter the number - "))
for i in range(1, n+1):
    print(n-i+1)
# Out:
# Enter the number - 5
# 5
# 4
# 3
# 2
# 1

# %%
n = int(input("Enter the number - "))
for i in range(-n, 0):
    print(-i)
# Out:
# Enter the number - 5
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# ---
