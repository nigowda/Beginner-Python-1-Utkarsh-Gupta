# %% [markdown]
# <a href="https://colab.research.google.com/github/nigowda/Beginner-Python-1-Utkarsh-Gupta/blob/main/09.Strings/Strings_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Strings

# %% [markdown]
# ---

# %% [markdown]
# ## Content
#
# 1. Introduction to strings in Python
# 2. Numeric representation of strings & ASCII
# 3. String formatting & manipulation
# 5. String methods
# 6. Palindrome
# 7. Mutability and Immutability

# %% [markdown]
# ---

# %% [markdown]
# ## What is a String?
# * String in Python is a sequence of characters.

# %% [markdown]
# ![Screenshot 2022-12-01 102412.png](data:image/png;base64,...)

# %% [markdown]
# * We can use single quotes ```' '``` or double quotes ```" "``` to create a string.
# * We can also use triple quotes ```''' '''``` to create multi-lined strings.

# %%
 'valid string'
# Out:
# 'valid string'

# %%
"valid string"
# Out:
# 'valid string'

# %%
'''valid string'''
# Out:
# 'valid string'

# %%
# Not a valid string
"valid string'
# Out:
#   File "<ipython-input-4-ae585965508a>", line 2
#     "valid string'
#     ^
# SyntaxError: unterminated string literal (detected at line 2)

# %% [markdown]
# ### **What type of characters can we have?**

# %% [markdown]
# * Small alphabets - [a - z]
# * Capital Alphabets - [A - Z]
# * Numbers - [0 - 9]
# * White spaces
# * Special characters

# %%
print("Whatever i write, UPPERCASE, lowercSE, $#@!#!@#")
# Out:
# Whatever i write, UPPERCASE, lowercSE, $#@!#!@#

# %% [markdown]
# ---

# %% [markdown]
# ### **Binary Representation**
# * Computer does not understand characters.
# * For every character let's have a pre defined number attached to it.

# %% [markdown]
# ### **Why is it important to have common representations of characters across all platforms?**
#
# * When different characters are mapped to different numbers on different platforms, if try to send a message from let's say Android to iOS, our message can be misinterpreted.
# * That is why we need consistent mapping of characters.

# %% [markdown]
# ![Screenshot 2022-12-01 103456.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2022-12-01 103539.png](data:image/png;base64,...)

# %% [markdown]
# ### **ASCII**
#
# * American Standard Code for Information Interchange.
# * ASCII used to have 256 characters.
# * With the help of this, the issue of consistency goes away.

# %% [markdown]
# ![Screenshot 2022-12-01 104112.png](data:image/png;base64,...)

# %%
# Compares ASCII values.
"a" > "A"
# Out:
# True

# %% [markdown]
# * ```ord()``` function can be used to get the ASCII value of a character.

# %%
ord("a")
# Out:
# 97

# %% [markdown]
# * ```chr()``` converts ASCII value to character.

# %%
chr(23123)
# Out:
# '婓'

# %% [markdown]
# ---

# %% [markdown]
# ### **Quiz-1**

# %% [markdown]
# What will be the output of the following code?
# ```python
# message = "Hello World!"
# i = 0
# while i < len(message):
#   if i % 2 == 0:
#     print(message[i], end = "")
#   i += 1
# ```
# A) `HloWrd`
#
# B) `Hlo ol`
#
# C) `eolWrd`
#
# D) `el or`
#
# **Answer**: A) `HloWrd`

# %% [markdown]
# ---

# %% [markdown]
# ### **String manipulation -**

# %% [markdown]
# * We can concatenate two strings using ```+``` operator.

# %%
"random1" + "random2"
# Out:
# 'random1random2'

# %% [markdown]
# * We can multiply a string using ```*``` operator.

# %%
"a" * 3 * 5
# Out:
# 'aaaaaaaaaaaaaaa'

# %% [markdown]
# * **Lexicographical order** - Order of words in a dictionary.

# %%
# In a dictionary, the second word would come first.
"zebra" > "adsahdjahsjhahfioahsfuaiusfhsuhfuishua"
# Out:
# True

# %%
"aAa" > "aaa"
# Out:
# False

# %% [markdown]
# ### **String formatting -**

# %%
l = 5
b = 10
a = l * b

# %%
# 1
print("Length =", l, "Breadth =", b, "and Area =", a)
# Out:
# Length = 5 Breadth = 10 and Area = 50

# %%
# 2
print("Length = {}, Breath = {}, and Area = {}".format(l, b, a))
# Out:
# Length = 5, Breath = 10, and Area = 50

# %% [markdown]
# ### **F-Strings**

# %%
# 3
print(f"Length = {l}, Breath = {b}, and Area = {a}")
# Out:
# Length = 5, Breath = 10, and Area = 50

# %% [markdown]
# ---

# %% [markdown]
# ### **String Methods**

# %% [markdown]
# ### ```.split()```

# %% [markdown]
# * The ```str.split()``` method converts a string into a list of characters based on a splitting criteria.

# %%
"4 5 6 7 8 9".split()
# Out:
# ['4', '5', '6', '7', '8', '9']

# %%
"This_is_a_underscore_separated_string".split("_")
# Out:
# ['This', 'is', 'a', 'underscore', 'separated', 'string']

# %% [markdown]
# ### ```.join()```

# %% [markdown]
# * The ```str.join()``` method does the exact opposite of splitting i.e. joining.

# %%
random = "This_is_a_underscore_separated_string".split("_")

# %%
" ".join(random)
# Out:
# 'This is a underscore separated string'

# %%
"-".join(random)
# Out:
# 'This-is-a-underscore-separated-string'

# %% [markdown]
# ### ```str()```

# %% [markdown]
# * We can use the```str()``` function to convert numbers to string.

# %%
str(45)
# Out:
# '45'

# %% [markdown]
# ### ```.find()```

# %% [markdown]
# * The ```.find()``` method can be used to find a substring inside a string.
# * It returns the **starting index** of the **first occurrence** of the substring that we are trying to find.

# %%
"this is a random string".find("is")
# Out:
# 2

# %% [markdown]
# * It returns ```-1``` if the substring is not present.

# %%
"this is a random string".find("adadsaf")
# Out:
# -1

# %% [markdown]
# ### ```.replace()```

# %% [markdown]
# * The ```.replace()``` method is used to replace a substring from the original string with the input we provide with and returns a new string.

# %%
random = "This is a random string that I have created"

# %%
# The orginal string is not updated.
random.replace("random", "SUPER RANDOM")
# Out:
# 'This is a SUPER RANDOM string that I have created'

# %% [markdown]
# ### ```.count()```

# %% [markdown]
# * The ```.count()``` method counts the number of occurrences of a substring inside a string.

# %%
random = "This is a random string that I have created"

# %%
random.count("a")
# Out:
# 5

# %%
random.count("random")
# Out:
# 1

# %% [markdown]
# ### ```.isdigit()```

# %% [markdown]
# * ```.isdigit()``` returns True if a character inside a string is a digit.
# * This method works only for integers.

# %%
"6".isdigit()
# Out:
# True

# %%
"aasda231321".isdigit()
# Out:
# False

# %%
"124143222".isdigit()
# Out:
# True

# %% [markdown]
# ### ```isalpha()```

# %% [markdown]
# * ```isalpha()``` returns True if a string only contains alphabets.

# %%
"aasda231321".isalpha()
# Out:
# False

# %%
"abc".isalpha()
# Out:
# True

# %% [markdown]
# ### ```isalnum()```

# %% [markdown]
# * `isalnum()` True if all the characters are alphanumeric, meaning either alphabets (a-Z) or numbers (0-9).
# * Note that whitespace, comma, dot, hyphen, and all other special characters are considered non-alphanumeric.

# %%
"Abc123".isalnum()
# Out:
# True

# %%
"23B Park Road, Lucknow, U.P. - 221100".isalnum()
# Out:
# False

# %% [markdown]
# ### ```isupper()``` and ```islower()```

# %%
"A".isupper()
# Out:
# True

# %%
"a".isupper()
# Out:
# False

# %%
"A".islower()
# Out:
# False

# %%
"a".islower()
# Out:
# True

# %% [markdown]
# ![summary](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ### **Palindrome**

# %% [markdown]
# #### **Question-1**
#
# Take a string input from the user and reverse that string.

# %%
s = input()
print(s[::-1])
# Out:
# bipin
# nipib

# %% [markdown]
# #### **Question-2**
#
# * Take a string input from the user.
# * Return `"PALINDROME"` if the string is a palindrome.
# * Otherwise return `"NOT A PALINDROME"`.

# %%
a = input()
# Out:
# abacaba

# %%
def check_palindrome(a):
    return "PALINDROME" if a == a[::-1] else "NOT A PALINDROME"

# %%
check_palindrome(a)
# Out:
# 'PALINDROME'

# %% [markdown]
# But, there is a problem.

# %%
a2 = input()
# Out:
# Naman

# %%
check_palindrome(a2)
# Out:
# 'NOT A PALINDROME'

# %% [markdown]
# #### Make all characters either lowercase using the `.lower()` or uppercase using the `.upper()` methods.

# %%
def check_palindrome(a):
    a = a.lower()
    return "PALINDROME" if a == a[::-1] else "NOT A PALINDROME"

# %%
check_palindrome(a2)
# Out:
# 'PALINDROME'

# %% [markdown]
# ---

# %% [markdown]
# ### **Quiz-2**

# %% [markdown]
# What will be the output of the following code?
# ```python
# message = "Hello World!"
# print(message.replace("o", "e"))
# ```
# A) `Helle Welle`
#
# B) `Helle Welle!`
#
# C) `Helle Werld!`
#
# D) `Hllo Wrld!`
#
# Answer: C) `Helle Werld!`

# %% [markdown]
# ### **Quiz-3**

# %% [markdown]
# What will be the output of the following code?
# ```python
# message = "Hello World!"
# print(message.find("o"))
# ```
# A) `8`
#
# B) `7`
#
# C) `4`
#
# D) `-1`
#
# Answer: C) `4`

# %% [markdown]
# ---

# %% [markdown]
# ### **Mutability and Immutability**

# %% [markdown]
# `Mutable`: whose value can be changed
#
# `Immutable`: whose value can't be changed
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/016/227/original/Screenshot_2022-10-12_at_10.10.40_AM.png?1665549635">
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/016/228/original/Screenshot_2022-10-12_at_10.10.55_AM.png?1665549675">

# %%
a = 3
a
# Out:
# 3

# %%
a = 4
a
# Out:
# 4

# %% [markdown]
# It seems that integers are mutable, but NO.
#
# Originally in Python, we are just changing the memory reference of `a` to point to `4` instead of changing its value to `4`.
#
# Only 3 data types in Python are `mutable`.
# - `lists`
# - `sets`
# - `dictionaries`
#
# Other data types such as `strings` and `tuples` are `immutable`.
#
# `id()` function in Python gives the memory address of a variable where it is stored.

# %%
id(a)
# Out:
# 140424322138448

# %%
a = 6

id(a)
# Out:
# 140424322138512

# %% [markdown]
# It can be seen that the memory address is changed. Hence, now `a` is pointing to somewhere else in the memory.

# %%
my_list =["Python", "C++", "Java"]
id(my_list)
# Out:
# 134540377816384

# %%
my_list[0] = "Python 3.5"
print(my_list)
print(id(my_list))
# Out:
# ['Python 3.5', 'C++', 'Java']
# 134540377816384

# %% [markdown]
# As lists are mutable, we can see that the same list created in the first cell is modified and the values are changed in the same memory location.

# %%
my_string  = "Scaled"
print(id(my_string))
# Out:
# 134540377842992

# %%
my_string[-1] = "a"  # Trying to change the character at the last index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-4a2d25e62232> in <cell line: 1>()
# ----> 1 my_string[4] = "a"  # Trying to change the character at index 4
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# - We receive an error since strings are immutable and we cannot change the value in place.
# - We can instead assign a new value to the same variable, which leads to the creation of a different memory space.

# %%
my_string = "Scaler"
print(id(my_string))
# Out:
# 134540377963568

# %% [markdown]
# ---
